# %%
# !pip install google-cloud-vision

# %%
import io
from collections import namedtuple
from PIL import Image, ImageDraw, ImageFont
from google.cloud import vision

def prepare_image_local(image_path):
    try:
        # Loads the image into memory
        with io.open(image_path, 'rb') as image_file:
            content = image_file.read()
        image = vision.Image(content=content)
        return image
    except Exception as e:
        print(e)
        return


class VisionAI:
    Label_Detection = namedtuple('Label_Detection', ('description', 'score'))
    Logo_Detection = namedtuple('Logo_Detection', ('description', 'score', 'bounding_poly'))
    Object_Detection = namedtuple('Object_Detection', ('name', 'score', 'bounding_poly'))
    Landmark_Detection = namedtuple('Landmark_Detection', ('description', 'score', 'bounding_poly', 'location'))
    Safe_Search_Detection = namedtuple('Safe_Search_Detection',
        ('adult_likelihood', 'spoof_likelihood', 'medical_likelihood', 'violence_likelihood', 'racy_likelihood'))
    Web_Detection = namedtuple('Web_Detection', ('web_entities', 'full_matching_images', 'visually_similar_images', 'pages_with_matching_images', 'best_guess_labels'))
    Web_Entity = namedtuple('Web_Entity', ('description', 'score'))
    Page_Matching_Image = namedtuple('Page_Matching_Image', ('url', 'page_title', 'full_matching_image_urls', 'partial_matching_image_urls'))
    Face_Detection = namedtuple('Face_Detection', ('detection_confidence', 'joy_likelihood', 'sorrow_likelihood', 'anger_likelihood', 'surprise_likelihood', 'under_exposed_likelihood',
        'blurred_likelihood', 'headwear_likelihood', 'bounding_poly'))

    Text_Detection = namedtuple('Text_Detection', ('description', 'bounding_poly'))

    def __init__(self, client, image):
        self.client = client
        self.image = image



    def text_detection(self):
        response = self.client.text_detection(image=self.image)
        texts = response.text_annotations
        if texts:
            results = []
            for text in texts:
                results.append(self.Text_Detection(text.description, text.bounding_poly.vertices))
            return results
        return

# %%
client = vision.ImageAnnotatorClient()
image_path='/content/Image.jpg'
image = prepare_image_local(image_path)
data =VisionAI(client,image)
data.text_detection()
# Out:
# [Text_Detection(description='NIC\nNo:\nBuilding\nQos\nNetwork\ninterface\nuntil 1990, most\nblocks\nof\nQoS\nMarking\nScheduling\ncard / Network\nadapters\nnetwork\nAdd a\nClassification → Application (NBAR - Network based Application\nRecognition)\nAccess Control List\nDate:\n→Tos, Cos\nFIFO\nPQ\nWEG\n-\ntag / change\nwere\n1st\nadapter\n2nd\nphysically\nord\nFirst in first Out\n-Primity Queueing\nweighted fair queueing\nsome\nbits.', bounding_poly=[x: 112
#  y: 52
#  , x: 991
#  y: 52
#  , x: 991
#  y: 709
#  , x: 112
#  y: 709
#  ]),
#  Text_Detection(description='NIC', bounding_poly=[x: 119
#  y: 124
#  , x: 154
#  y: 124
#  , x: 154
#  y: 138
#  , x: 119
#  y: 138
#  ]),
#  Text_Detection(description='No', bounding_poly=[x: 163
#  y: 62
#  , x: 185
#  y: 62
#  , x: 185
#  y: 73
#  , x: 163
#  y: 73
#  ]),
#  Text_Detection(description=':', bounding_poly=[x: 191
#  y: 62
#  , x: 196
#  y: 62
#  , x: 196
#  y: 73
#  , x: 191
#  y: 73
#  ]),
#  Text_Detection(description='Building', bounding_poly=[x: 112
#  y: 225
#  , x: 189
#  y: 226
#  , x: 189
#  y: 247
#  , x: 112
#  y: 246
#  ]),
#  Text_Detection(description='Qos', bounding_poly=[x: 114
#  y: 311
#  , x: 160
#  y: 312
#  , x: 160
#  y: 329
#  , x: 114
#  y: 328
#  ]),
#  Text_Detection(description='Network', bounding_poly=[x: 196
#  y: 123
#  , x: 282
#  y: 123
#  , x: 282
#  y: 136
#  , x: 196
#  y: 136
#  ]),
#  Text_Detection(description='interface', bounding_poly=[x: 325
#  y: 119
#  , x: 421
#  y: 119
#  , x: 421
#  y: 136
#  , x: 325
#  y: 136
#  ]),
#  Text_Detection(description='until', bounding_poly=[x: 195
#  y: 160
#  , x: 241
#  y: 160
#  , x: 241
#  y: 175
#  , x: 195
#  y: 175
#  ]),
#  Text_Detection(description='1990', bounding_poly=[x: 265
#  y: 160
#  , x: 306
#  y: 160
#  , x: 306
#  y: 175
#  , x: 265
#  y: 175
#  ]),
#  Text_Detection(description=',', bounding_poly=[x: 305
#  y: 160
#  , x: 313
#  y: 160
#  , x: 313
#  y: 175
#  , x: 305
#  y: 175
#  ]),
#  Text_Detection(description='most', bounding_poly=[x: 344
#  y: 160
#  , x: 385
#  y: 158
#  , x: 386
#  y: 173
#  , x: 345
#  y: 175
#  ]),
#  Text_Detection(description='blocks', bounding_poly=[x: 225
#  y: 221
#  , x: 282
#  y: 220
#  , x: 282
#  y: 235
#  , x: 225
#  y: 236
#  ]),
#  Text_Detection(description='of', bounding_poly=[x: 315
#  y: 223
#  , x: 335
#  y: 223
#  , x: 335
#  y: 238
#  , x: 315
#  y: 238
#  ]),
#  Text_Detection(description='QoS', bounding_poly=[x: 364
#  y: 219
#  , x: 400
#  y: 219
#  , x: 400
#  y: 234
#  , x: 364
#  y: 234
#  ]),
#  Text_Detection(description='Marking', bounding_poly=[x: 267
#  y: 391
#  , x: 356
#  y: 391
#  , x: 356
#  y: 418
#  , x: 267
#  y: 418
#  ]),
#  Text_Detection(description='Scheduling', bounding_poly=[x: 265
#  y: 506
#  , x: 369
#  y: 508
#  , x: 368
#  y: 536
#  , x: 264
#  y: 534
#  ]),
#  Text_Detection(description='card', bounding_poly=[x: 463
#  y: 110
#  , x: 507
#  y: 110
#  , x: 507
#  y: 133
#  , x: 463
#  y: 133
#  ]),
#  Text_Detection(description='/', bounding_poly=[x: 534
#  y: 110
#  , x: 550
#  y: 110
#  , x: 550
#  y: 132
#  , x: 534
#  y: 132
#  ]),
#  Text_Detection(description='Network', bounding_poly=[x: 559
#  y: 110
#  , x: 648
#  y: 110
#  , x: 648
#  y: 132
#  , x: 559
#  y: 132
#  ]),
#  Text_Detection(description='adapters', bounding_poly=[x: 531
#  y: 156
#  , x: 609
#  y: 155
#  , x: 609
#  y: 175
#  , x: 531
#  y: 176
#  ]),
#  Text_Detection(description='network', bounding_poly=[x: 413
#  y: 157
#  , x: 492
#  y: 158
#  , x: 492
#  y: 172
#  , x: 413
#  y: 171
#  ]),
#  Text_Detection(description='Add', bounding_poly=[x: 511
#  y: 388
#  , x: 540
#  y: 388
#  , x: 540
#  y: 402
#  , x: 511
#  y: 402
#  ]),
#  Text_Detection(description='a', bounding_poly=[x: 555
#  y: 388
#  , x: 568
#  y: 388
#  , x: 568
#  y: 402
#  , x: 555
#  y: 402
#  ]),
#  Text_Detection(description='Classification', bounding_poly=[x: 278
#  y: 273
#  , x: 410
#  y: 273
#  , x: 410
#  y: 288
#  , x: 278
#  y: 288
#  ]),
#  Text_Detection(description='→', bounding_poly=[x: 445
#  y: 267
#  , x: 481
#  y: 266
#  , x: 481
#  y: 291
#  , x: 445
#  y: 292
#  ]),
#  Text_Detection(description='Application', bounding_poly=[x: 514
#  y: 265
#  , x: 621
#  y: 263
#  , x: 621
#  y: 289
#  , x: 514
#  y: 291
#  ]),
#  Text_Detection(description='(', bounding_poly=[x: 645
#  y: 263
#  , x: 654
#  y: 263
#  , x: 654
#  y: 288
#  , x: 645
#  y: 288
#  ]),
#  Text_Detection(description='NBAR', bounding_poly=[x: 652
#  y: 262
#  , x: 701
#  y: 261
#  , x: 701
#  y: 287
#  , x: 652
#  y: 288
#  ]),
#  Text_Detection(description='-', bounding_poly=[x: 708
#  y: 262
#  , x: 718
#  y: 262
#  , x: 718
#  y: 287
#  , x: 708
#  y: 287
#  ]),
#  Text_Detection(description='Network', bounding_poly=[x: 727
#  y: 261
#  , x: 802
#  y: 260
#  , x: 802
#  y: 286
#  , x: 727
#  y: 287
#  ]),
#  Text_Detection(description='based', bounding_poly=[x: 820
#  y: 259
#  , x: 871
#  y: 258
#  , x: 871
#  y: 284
#  , x: 820
#  y: 285
#  ]),
#  Text_Detection(description='Application', bounding_poly=[x: 887
#  y: 258
#  , x: 984
#  y: 256
#  , x: 984
#  y: 282
#  , x: 887
#  y: 284
#  ]),
#  Text_Detection(description='Recognition', bounding_poly=[x: 883
#  y: 287
#  , x: 977
#  y: 286
#  , x: 977
#  y: 307
#  , x: 883
#  y: 308
#  ]),
#  Text_Detection(description=')', bounding_poly=[x: 979
#  y: 286
#  , x: 990
#  y: 286
#  , x: 990
#  y: 306
#  , x: 979
#  y: 306
#  ]),
#  Text_Detection(description='Access', bounding_poly=[x: 513
#  y: 308
#  , x: 571
#  y: 307
#  , x: 571
#  y: 324
#  , x: 513
#  y: 325
#  ]),
#  Text_Detection(description='Control', bounding_poly=[x: 593
#  y: 307
#  , x: 657
#  y: 306
#  , x: 657
#  y: 323
#  , x: 593
#  y: 324
#  ]),
#  Text_Detection(description='List', bounding_poly=[x: 680
#  y: 306
#  , x: 724
#  y: 305
#  , x: 724
#  y: 321
#  , x: 680
#  y: 322
#  ]),
#  Text_Detection(description='Date', bounding_poly=[x: 626
#  y: 52
#  , x: 663
#  y: 53
#  , x: 663
#  y: 65
#  , x: 626
#  y: 64
#  ]),
#  Text_Detection(description=':', bounding_poly=[x: 665
#  y: 54
#  , x: 669
#  y: 54
#  , x: 669
#  y: 65
#  , x: 665
#  y: 65
#  ]),
#  Text_Detection(description='→', bounding_poly=[x: 451
#  y: 424
#  , x: 475
#  y: 424
#  , x: 475
#  y: 444
#  , x: 451
#  y: 444
#  ]),
#  Text_Detection(description='Tos', bounding_poly=[x: 504
#  y: 424
#  , x: 535
#  y: 424
#  , x: 535
#  y: 444
#  , x: 504
#  y: 444
#  ]),
#  Text_Detection(description=',', bounding_poly=[x: 535
#  y: 424
#  , x: 546
#  y: 424
#  , x: 546
#  y: 444
#  , x: 535
#  y: 444
#  ]),
#  Text_Detection(description='Cos', bounding_poly=[x: 559
#  y: 424
#  , x: 591
#  y: 424
#  , x: 591
#  y: 444
#  , x: 559
#  y: 444
#  ]),
#  Text_Detection(description='FIFO', bounding_poly=[x: 517
#  y: 499
#  , x: 572
#  y: 499
#  , x: 572
#  y: 515
#  , x: 517
#  y: 515
#  ]),
#  Text_Detection(description='PQ', bounding_poly=[x: 515
#  y: 538
#  , x: 541
#  y: 538
#  , x: 541
#  y: 557
#  , x: 515
#  y: 557
#  ]),
#  Text_Detection(description='WEG', bounding_poly=[x: 511
#  y: 583
#  , x: 555
#  y: 584
#  , x: 555
#  y: 600
#  , x: 511
#  y: 599
#  ]),
#  Text_Detection(description='-', bounding_poly=[x: 595
#  y: 510
#  , x: 602
#  y: 510
#  , x: 602
#  y: 512
#  , x: 595
#  y: 512
#  ]),
#  Text_Detection(description='tag', bounding_poly=[x: 584
#  y: 385
#  , x: 618
#  y: 384
#  , x: 619
#  y: 411
#  , x: 585
#  y: 412
#  ]),
#  Text_Detection(description='/', bounding_poly=[x: 623
#  y: 384
#  , x: 644
#  y: 383
#  , x: 645
#  y: 409
#  , x: 624
#  y: 410
#  ]),
#  Text_Detection(description='change', bounding_poly=[x: 648
#  y: 382
#  , x: 714
#  y: 379
#  , x: 715
#  y: 406
#  , x: 649
#  y: 409
#  ]),
#  Text_Detection(description='were', bounding_poly=[x: 638
#  y: 162
#  , x: 681
#  y: 162
#  , x: 681
#  y: 171
#  , x: 638
#  y: 171
#  ]),
#  Text_Detection(description='1st', bounding_poly=[x: 613
#  y: 623
#  , x: 630
#  y: 623
#  , x: 630
#  y: 633
#  , x: 613
#  y: 633
#  ]),
#  Text_Detection(description='adapter', bounding_poly=[x: 684
#  y: 116
#  , x: 772
#  y: 116
#  , x: 772
#  y: 138
#  , x: 684
#  y: 138
#  ]),
#  Text_Detection(description='2nd', bounding_poly=[x: 608
#  y: 658
#  , x: 633
#  y: 656
#  , x: 634
#  y: 669
#  , x: 609
#  y: 671
#  ]),
#  Text_Detection(description='physically', bounding_poly=[x: 708
#  y: 155
#  , x: 804
#  y: 155
#  , x: 804
#  y: 178
#  , x: 708
#  y: 178
#  ]),
#  Text_Detection(description='ord', bounding_poly=[x: 610
#  y: 698
#  , x: 634
#  y: 698
#  , x: 634
#  y: 709
#  , x: 610
#  y: 709
#  ]),
#  Text_Detection(description='First', bounding_poly=[x: 617
#  y: 498
#  , x: 664
#  y: 498
#  , x: 664
#  y: 515
#  , x: 617
#  y: 515
#  ]),
#  Text_Detection(description='in', bounding_poly=[x: 676
#  y: 498
#  , x: 691
#  y: 498
#  , x: 691
#  y: 514
#  , x: 676
#  y: 514
#  ]),
#  Text_Detection(description='first', bounding_poly=[x: 712
#  y: 497
#  , x: 752
#  y: 497
#  , x: 752
#  y: 514
#  , x: 712
#  y: 514
#  ]),
#  Text_Detection(description='Out', bounding_poly=[x: 771
#  y: 497
#  , x: 798
#  y: 497
#  , x: 798
#  y: 513
#  , x: 771
#  y: 513
#  ]),
#  Text_Detection(description='-Primity', bounding_poly=[x: 594
#  y: 539
#  , x: 681
#  y: 536
#  , x: 682
#  y: 566
#  , x: 595
#  y: 569
#  ]),
#  Text_Detection(description='Queueing', bounding_poly=[x: 708
#  y: 535
#  , x: 797
#  y: 531
#  , x: 798
#  y: 560
#  , x: 709
#  y: 564
#  ]),
#  Text_Detection(description='weighted', bounding_poly=[x: 613
#  y: 577
#  , x: 702
#  y: 574
#  , x: 703
#  y: 606
#  , x: 614
#  y: 609
#  ]),
#  Text_Detection(description='fair', bounding_poly=[x: 729
#  y: 573
#  , x: 773
#  y: 572
#  , x: 774
#  y: 604
#  , x: 730
#  y: 605
#  ]),
#  Text_Detection(description='queueing', bounding_poly=[x: 792
#  y: 571
#  , x: 891
#  y: 568
#  , x: 892
#  y: 600
#  , x: 793
#  y: 603
#  ]),
#  Text_Detection(description='some', bounding_poly=[x: 740
#  y: 390
#  , x: 782
#  y: 389
#  , x: 782
#  y: 398
#  , x: 740
#  y: 399
#  ]),
#  Text_Detection(description='bits', bounding_poly=[x: 805
#  y: 379
#  , x: 846
#  y: 380
#  , x: 845
#  y: 396
#  , x: 805
#  y: 395
#  ]),
#  Text_Detection(description='.', bounding_poly=[x: 846
#  y: 381
#  , x: 853
#  y: 381
#  , x: 853
#  y: 396
#  , x: 846
#  y: 396
#  ])]

# %%
from importlib.resources import path
import os,io
from google.cloud import vision
from google.cloud import vision_v1
from google.cloud.vision_v1 import types
import pandas as pd

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = r'/content/sample_data/keen-boulder-390208-1a07e1a056e5.json'
client = vision.ImageAnnotatorClient()

def detectText(img):
    with io.open(img,'rb') as image:
        content = image.read()
    image_ = vision_v1.types.Image(content =content)
    response = client.text_detection(image=image_)
    texts = response.text_annotations

    df=pd.DataFrame(columns = ['locale','description'])
    for text in texts:
        df = df.append(
            dict(
                locale = text.locale,
                description = text.description

            ),
            ignore_index = True
        )
    return df

FILE_NAME = 'Image.jpg'
FOLDER_PATH= r'/content'
print(detectText(os.path.join(FOLDER_PATH,FILE_NAME)))
# Out:
#    locale                                        description
# 0      en  NIC\nNo:\nBuilding\nQos\nNetwork\ninterface\nu...
# 1                                                        NIC
# 2                                                         No
# 3                                                          :
# 4                                                   Building
# ..    ...                                                ...
# 64                                                      fair
# 65                                                  queueing
# 66                                                      some
# 67                                                      bits
# 68                                                         .
#
# [69 rows x 2 columns]
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
# <ipython-input-19-3b16600ac9fd>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(
